# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
import os, sys
ruta = os.path.dirname(os.getcwd())
sys.path.append(ruta)

# %%
import src.utils.visualization_tb as vi

# %%
serie = pd.Series({"Find the subject and data" : 3 ,"Clean data and make it usable" :4, "Split train and test" :5  , "Understand data and work with graphs" : 6, "Find the best model": 15 ,"Flask API" : 2 , "Streamlit Dashboard" : 7 ,"Answering project questions" :0.5, "MySQL":3, "Presentation": 6})
serie
# Out:
# Find the subject and data                3.0
# Clean data and make it usable            4.0
# Split train and test                     5.0
# Understand data and work with graphs     6.0
# Find the best model                     15.0
# Flask API                                2.0
# Streamlit Dashboard                      7.0
# Answering project questions              0.5
# MySQL                                    3.0
# Presentation                             6.0
# dtype: float64

# %%
#Piechart trabajado

vi.pie_chart(serie)
plt.savefig(".." + os.sep + "reports" + os.sep + "images" + os.sep + "pie_chart.jpg")
