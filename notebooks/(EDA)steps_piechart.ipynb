# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
import os, sys
ruta = os.path.dirname(os.getcwd())
sys.path.append(ruta)

# %%
import src.utils.visualization_tb as vi

# %%
serie = pd.Series({"Find the subject and data" : 8 ,"Define hipotesis" :1, "Get data" : 1 ,"Clean data" :7, "Understand data and work with graphs" : 13 ,"Conclusion" :2, "Flask API" : 4 , "Streamlit Dashboard" : 4 ,"Answering project questions" :3, "MySQL":3.5, "Presentation": 4})
serie
# Out:
# Find the subject and data                8.0
# Define hipotesis                         1.0
# Get data                                 1.0
# Clean data                               7.0
# Understand data and work with graphs    13.0
# Conclusion                               2.0
# Flask API                                4.0
# Streamlit Dashboard                      4.0
# Answering project questions              3.0
# MySQL                                    3.5
# Presentation                             4.0
# dtype: float64

# %%
#Piechart trabajado

vi.pie_chart(serie)
plt.savefig(".." + os.sep + "reports" + os.sep + "images" + os.sep + "pie_chart.jpg")
